# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **No Supervisado: PCA**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en aplicar PCA a un dataset de imágenes con diferentes objetivos y compromisos. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### El problema de negocio
#
# El Caesar Palace de las Vegas está planificando la instalación de mil quininetas microcámaras en los accesos a sus instalaciones para las próximas sesiones del "Poker World Championship". Estas microcámaras tienen la peculiaridad de que son capaces de tomar fotos encuadradas de las caras y la desventaja de que no tienen un gran ancho de banda de comunicación. (Las había de más ancho y de mayor precio...). NOTA: El ancho de banda limita el tamaño de las imágenes que pueden enviar las microcámaras).
#
# El objetivo de las microcámaras es el de detectar personas "non-gratas" en tiempo real, pudiendo posprocesar las imágenes para poder detectar si han accedido a las instalaciones personas que estuvieran perseguidas por la ley, en los bancos de datos de los casinos identificadas como "peligrosas" (no se sabe si para el resto de personas o para los beneficios de los casinos) y en las listas de no admisión de jugadores adictos. Por eso no necesitan procesar los datos en tiempo real, pero sí enviarlos a un repositorio central.
#
# ¿Cuál es su problema? O bien comprimen las imágenes y las procesan comprimidas en cada microcámara (pueden comprimir muy rápido pero no tienen cpu para procesarlas sin comprimir) o bien las comprimen y las mandan a un servidor central muy rápido (por eso ti) donde se descomprimirían y se analizarían. Analizar quiere decir en este contexto, pasarles un modelo de clasificación que determine si la persona de la imagen es una de las listas prohibidas (o sea que clasifique la imágen).
#
# Nos han enviado un dataset y con él debemos estudiar cuál de las dos soluciones es más interesante y dar recomendaciones al respecto. Vamos a ello.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import ToolBox as tb
import bootcampviztools as viz
import scipy.cluster.hierarchy as shc

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.datasets import fetch_olivetti_faces
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, accuracy_score, balanced_accuracy_score

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ### #1 MODELO DE BASE

# %% [markdown]
# **Objetivo:** Construir un modelo baseline de clasficación de imágenes que las trate sin comprimir (es decir usando todos sus píxeles).

# %% [markdown]
# Para conseguir el objetivo, primero descarga el dataset de las caras de Olivetti que ya has utilizado anteriormente, empleando las funciones de sklearn necesarias. Luego, construye un clasificador con el modelo que consideres más apropiado y todas las features del dataset. Eso sí, recuerda hacer lo siguiente:
#
# 1. Construir un data frame con los datos
# 2. Hacer un split en train y test con al menos 80 instancias en el test y estratificado según el target. Este split se ha de mantener en el resto de la práctica
# 3. Hacer un quick miniEDA o justificar el no hacerlo.
# 4. Medir la recall media (“balanced_accuracy”) sobre cross validation con 5 folds y sobre el conjunto de test y guarda ambas para usarlas como baseline en las siguientes partes

# %%
X = pd.DataFrame(fetch_olivetti_faces().data, columns=[f"PX{i}" for i in range(1, fetch_olivetti_faces().data.shape[1] +1)])

# %%
X
# Out:
#           PX1       PX2       PX3       PX4       PX5       PX6       PX7  \
# 0    0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1    0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2    0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3    0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4    0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  0.632231  0.648760  0.640496  0.661157
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 397  0.500000  0.533058  0.607438  0.628099  0.657025  0.632231  0.657025
# 398  0.214876  0.219008  0.219008  0.223140  0.210744  0.202479  0.276859
# 399  0.516529  0.462810  0.280992  0.252066  0.247934  0.367769  0.574380
#
#           PX8       PX9      PX10  ...    PX4087    PX4088    PX4089  \
# 0    0.677686  0.690083  0.685950  ...  0.665289  0.669421  0.652893
# 1    0.702479  0.710744  0.702479  ...  0.136364  0.157025  0.136364
# 2    0.685950  0.702479  0.698347  ...  0.074380  0.132231  0.181818
# 3    0.404959  0.483471  0.516529  ...  0.652893  0.636364  0.657025
# 4    0.714876  0.723140  0.731405  ...  0.190083  0.161157  0.177686
# ..        ...       ...       ...  ...       ...       ...       ...
# 395  0.636364  0.665289  0.698347  ...  0.388430  0.396694  0.264463
# 396  0.512397  0.574380  0.628099  ...  0.380165  0.334711  0.289256
# 397  0.669421  0.673554  0.702479  ...  0.194215  0.148760  0.152893
# 398  0.400826  0.487603  0.549587  ...  0.446281  0.392562  0.367769
# 399  0.615702  0.661157  0.615702  ...  0.276859  0.264463  0.293388
#
#        PX4090    PX4091    PX4092    PX4093    PX4094    PX4095    PX4096
# 0    0.661157  0.475207  0.132231  0.148760  0.152893  0.161157  0.157025
# 1    0.148760  0.152893  0.152893  0.152893  0.152893  0.152893  0.152893
# 2    0.136364  0.128099  0.148760  0.144628  0.140496  0.148760  0.152893
# 3    0.685950  0.727273  0.743802  0.764463  0.752066  0.752066  0.739669
# 4    0.173554  0.177686  0.177686  0.177686  0.177686  0.173554  0.173554
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.099174  0.181818  0.243802  0.247934  0.161157  0.157025  0.136364
# 396  0.285124  0.338843  0.404959  0.458678  0.487603  0.512397  0.549587
# 397  0.161157  0.161157  0.173554  0.157025  0.177686  0.148760  0.190083
# 398  0.409091  0.479339  0.524793  0.545455  0.574380  0.590909  0.603306
# 399  0.301653  0.293388  0.322314  0.322314  0.359504  0.355372  0.384298
#
# [400 rows x 4096 columns]

# %%
plt.imshow(X.loc[0].values.reshape(64,64), cmap = "grey")

# %%
X.describe()
# Out:
#               PX1         PX2         PX3         PX4         PX5         PX6  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean     0.400134    0.434236    0.476281    0.518481    0.554845    0.588729
# std      0.180695    0.189504    0.194742    0.193313    0.188593    0.178481
# min      0.086777    0.066116    0.090909    0.041322    0.107438    0.107438
# 25%      0.243802    0.267562    0.314050    0.383264    0.446281    0.515496
# 50%      0.392562    0.458678    0.512397    0.545455    0.584711    0.615702
# 75%      0.528926    0.575413    0.636364    0.666322    0.702479    0.714876
# max      0.805785    0.822314    0.871901    0.892562    0.871901    0.871901
#
#               PX7         PX8         PX9        PX10  ...      PX4087  \
# count  400.000000  400.000000  400.000000  400.000000  ...  400.000000
# mean     0.621426    0.647510    0.664814    0.676591  ...    0.363079
# std      0.167109    0.155024    0.147616    0.143583  ...    0.164952
# min      0.115702    0.115702    0.119835    0.140496  ...    0.049587
# 25%      0.544421    0.581612    0.599174    0.611570  ...    0.227273
# 50%      0.652893    0.669421    0.683884    0.702479  ...    0.367769
# 75%      0.735537    0.757231    0.772727    0.780992  ...    0.484504
# max      0.871901    0.871901    0.871901    0.871901  ...    0.793388
#
#            PX4088      PX4089      PX4090      PX4091      PX4092      PX4093  \
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.000000
# mean     0.367221    0.363027    0.355506    0.340196    0.338657    0.335909
# std      0.181861    0.181611    0.188709    0.186088    0.189256    0.195280
# min      0.037190    0.053719    0.049587    0.033058    0.012397    0.049587
# 25%      0.214876    0.219008    0.197314    0.177686    0.177686    0.173554
# 50%      0.367769    0.342975    0.334711    0.320248    0.314050    0.299587
# 75%      0.496901    0.500000    0.500000    0.479339    0.462810    0.462810
# max      0.904959    0.888430    0.896694    0.826446    0.863636    0.921488
#
#            PX4094      PX4095      PX4096
# count  400.000000  400.000000  400.000000
# mean     0.321415    0.313647    0.310455
# std      0.187842    0.183616    0.180635
# min      0.057851    0.061983    0.033058
# 25%      0.173554    0.173554    0.172521
# 50%      0.289256    0.270661    0.272727
# 75%      0.446281    0.414256    0.417355
# max      0.929752    0.884298    0.822314
#
# [8 rows x 4096 columns]

# %%
y = pd.Series(fetch_olivetti_faces().target, name= "target")

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 395    39
# 396    39
# 397    39
# 398    39
# 399    39
# Name: target, Length: 400, dtype: int64

# %%
df = pd.concat((X, y), axis= 1)

# %% [markdown]
# #### *Train, test split*

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify= y, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (320, 4096) (80, 4096) (320,) (80,)

# %% [markdown]
# #### *Mini EDA*

# %% [markdown]
# *No voy a hacer mini EDA porque con los píxeles poco se puede ver, además es un número inabarcable de features. Tampoco en principio necesita transformaciones, ya que todos los valores están ya escalados en una escala de 0 a 1.*

# %% [markdown]
# #### *Baseline (Logistic Regression)*

# %%
bas_lr = LogisticRegression(max_iter= 10000)
cv = cross_val_score(bas_lr, X_train, y_train, cv = 5, scoring= "balanced_accuracy").mean()
cv
# Out:
# np.float64(0.9550000000000001)

# %%
cv_baseline = cv
cv_baseline
# Out:
# np.float64(0.9550000000000001)

# %%
bas_lr.fit(X_train, y_train)
pred_test = bas_lr.predict(X_test)
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      0.50      0.67         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       0.67      1.00      0.80         2
#            8       1.00      1.00      1.00         2
#            9       1.00      0.50      0.67         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#           30       1.00      1.00      1.00         2
#           31       1.00      1.00      1.00         2
#           32       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       1.00      1.00      1.00         2
#           36       1.00      1.00      1.00         2
#           37       1.00      1.00      1.00         2
#           38       1.00      1.00      1.00         2
#           39       0.67      1.00      0.80         2
#
#     accuracy                           0.97        80
#    macro avg       0.98      0.97      0.97        80
# weighted avg       0.98      0.97      0.97        80

# %%
recall_baseline = balanced_accuracy_score(y_test, pred_test)
recall_baseline
# Out:
# np.float64(0.975)

# %%
plt.figure(figsize=(20,20))
c_matrix = ConfusionMatrixDisplay(confusion_matrix= "cm")
c_matrix.from_predictions(y_test, pred_test)

# %% [markdown]
# *Con un modelo tan sencillo como la regresión logística hemos conseguido unos resultados muy buenos, aunque hay un dos personas a las que ha confundido en una ocasión.*

# %% [markdown]
# ### #2 MODELO PARA LAS MICROCÁMARAS
# **Objetivo:** Construir un modelo que pueda funcionar en las microcámaras, es decir que pueda funcionar con datos comprimidos.

# %% [markdown]
# Para cumplir con el objetivo se os ocurre emplear la doble propiedad de la PCA, que permite comprimir datos y mantener la capacidad informativa de estos. Sigue los siguientes pasos:
# 1. Instancia un objeto PCA sobre los datos de Train sin especificar ni componentes ni varianza explicada (o sea sin pasar argumentos).
# 2. Escoge un rango de valores para el número de PCAs que permitan por lo menos una compresión de la imagen de entre el 0.2% y el 2.5% (prueba al menos 5 valores). NOTA: La compresión es la reducción total, es decir una reducción del 1% quiere decir que el dataset se reduce a un 1% de su tamaño original)
# 3. Para el rango anterior entrena un modelo de clasificación y apunta su scoring en una validación cruzada de 5 folds y métrica el recall medio y su scoring contra test.
# 4. Muestra en un dataframe el valor de numero de componentes principales empleado, el scoring en CV, el scoring contra test, el % de compresión, la diferencia con el scoring de CV del modelo base, la diferencia con el scoring en test.
# 5. Escoge el número de componentes que permitirían tener la mayor compresión con una pérdida inferior a 3 puntos porcentuales tanto en CV como en test. Si no hay escoge el que tenga una pérdida inferior a 5 puntos porcentuales.

# %%
pca = PCA()
pca.fit(X_train)
# Out:
# PCA()

# %%
pca.components_
# Out:
# array([[ 0.00459811,  0.00752321,  0.00943571, ..., -0.00154155,
#         -0.00472106, -0.00446059],
#        [ 0.02820925,  0.03321972,  0.0384042 , ..., -0.02890605,
#         -0.02632676, -0.02369073],
#        [-0.00140596,  0.00060532, -0.00071673, ...,  0.02041166,
#          0.01873668,  0.01695077],
#        ...,
#        [ 0.01070371, -0.00140016, -0.0095095 , ...,  0.03351006,
#          0.02383193, -0.01699253],
#        [ 0.01162338,  0.02211684, -0.00697685, ...,  0.00035183,
#          0.00974759, -0.02117926],
#        [-0.01587876,  0.01272141, -0.01215012, ...,  0.00847955,
#          0.01521706,  0.01126798]], shape=(320, 4096), dtype=float32)

# %%
len(X_train.columns) * 0.025
# Out:
# 102.4

# %%
for i in np.arange(0.005, 0.026, 0.005):
    print(f"Para una compresión del {i * 100}%, la varianza conservada es del {pca.explained_variance_ratio_.cumsum()[(round(len(X_train.columns) * i) -1)] * 100}%")
# Out:
# Para una compresión del 0.5%, la varianza conservada es del 76.36283874511719%
# Para una compresión del 1.0%, la varianza conservada es del 85.69405364990234%
# Para una compresión del 1.5%, la varianza conservada es del 89.84442138671875%
# Para una compresión del 2.0%, la varianza conservada es del 92.56912994384766%
# Para una compresión del 2.5%, la varianza conservada es del 94.36705017089844%

# %%
dict_cv_test = {
    "pc_number": [],
    "cv_score": [],
    "test_score": [],
    "%_comp": [],
    "cv_vs_baseline": [],
    "test_vs_baseline": []
}
for i in np.arange(0.005, 0.026, 0.005):
    n_components = (round(len(X_train.columns) * i))
    pca = PCA(n_components= n_components)
    X_train_comp = pca.fit_transform(X_train)
    X_test_comp = pca.transform(X_test)
    log_reg = LogisticRegression(max_iter=10000)
    log_reg.fit(X_train_comp, y_train)
    cv = cross_val_score(log_reg, X_train_comp, y_train, cv = 5, scoring= "balanced_accuracy").mean()
    recall = balanced_accuracy_score(y_test, log_reg.predict(X_test_comp))
    dict_cv_test["pc_number"].append(n_components)
    dict_cv_test["cv_score"].append(cv)
    dict_cv_test["test_score"].append(recall)
    dict_cv_test["%_comp"].append(f"{i * 100}%")
    dict_cv_test["cv_vs_baseline"].append(round(cv - cv_baseline, 2))
    dict_cv_test["test_vs_baseline"].append(round(recall - recall_baseline, 2))

df_comparacion = pd.DataFrame(dict_cv_test)

# %%
df_comparacion
# Out:
#    pc_number  cv_score  test_score %_comp  cv_vs_baseline  test_vs_baseline
# 0         20    0.9525      0.9375   0.5%            -0.0             -0.04
# 1         41    0.9575      0.9625   1.0%             0.0             -0.01
# 2         61    0.9575      0.9750   1.5%             0.0              0.00
# 3         82    0.9600      0.9625   2.0%             0.0             -0.01
# 4        102    0.9600      0.9625   2.5%             0.0             -0.01

# %% [markdown]
# *Curiosamente el que mejor rendimiento ha obtenido con test es el comprimido al 1.5%, mejor que al 2 y al 2.5%*

# %% [markdown]
# ### #3 COMPRESION PARA CLASIFICACION POSTERIOR

# %% [markdown]
# **Objetivo**: Obtener el número de componentes que permita una compresión menor y al tiempo que el modelo en el servidor central no baje su rendimiento respecto a no usar imágenes comprimidas.

# %% [markdown]
# Para esta parte la idea que se os ha ocurrido es emplear también la PCA como compresor ya que así siempre podrían pasar a la opción anterior si eso fuese suficiente. Pero en este caso no vamos a utilizar el dataset comprimido con las PCAs para detectar las caras, sino el dataset una vez descomprimido (recuerda que puede emplear `inverse_transform` para "descomprimir"). Los pasos a seguir son:
#
# 1. Escoge un rango de valores que  permitan una compresión aún mayor (recuerda que el ancho de banda es mínimo) entre el 1 por mil y el 1 por ciento. Escoge 5 valores de número de PCAs que permitan movernos en ese rango.
# 2. Para cada uno de esos valores: aplica la PCA al X_train, obten un X_train_unzipped aplicando la inversa de la PCA y entrena un modelo de clasificación y pruébalo contra test, apunta el balanced accuracy.
# 3. Crea un dataframe o haz un visualización comparando como es la medidad de balance accuracy para cada valor de número de pcas escogido y cuál su factor de compresión.
# 4. Sabiendo que no podemos perder más de 3 puntos porcentuales respecto al baseline, ¿qué numero de PCA escogerías?

# %%
dict_cv_test = {
    "pc_number": [],
    "cv_score": [],
    "test_score": [],
    "%_comp": [],
    "cv_vs_baseline": [],
    "test_vs_baseline": []
}
for i in np.linspace(0.001, 0.01, 15):
    n_components = (round(len(X_train.columns) * i))
    pca = PCA(n_components= n_components)
    X_train_comp = pca.fit_transform(X_train)
    X_train_unzipped = pca.inverse_transform(X_train_comp)
    X_test_comp = pca.transform(X_test)
    X_test_unizipped = pca.inverse_transform(X_test_comp)
    log_reg = LogisticRegression(max_iter=10000)
    log_reg.fit(X_train_unzipped, y_train)
    cv = cross_val_score(log_reg, X_train_unzipped, y_train, cv = 5, scoring= "balanced_accuracy").mean()
    recall = balanced_accuracy_score(y_test, log_reg.predict(X_test_unizipped))
    dict_cv_test["pc_number"].append(n_components)
    dict_cv_test["cv_score"].append(cv)
    dict_cv_test["test_score"].append(recall)
    dict_cv_test["%_comp"].append(f"{i * 100}%")
    dict_cv_test["cv_vs_baseline"].append(round(cv - cv_baseline, 2))
    dict_cv_test["test_vs_baseline"].append(round(recall - recall_baseline, 2))

df_comparacion = pd.DataFrame(dict_cv_test)

# %%
pd.options.display.float_format = '{:.4f}'.format
df_comparacion["cv_vs_baseline"] = df_comparacion.cv_score - cv_baseline
df_comparacion.test_vs_baseline = df_comparacion.test_score - recall_baseline
df_comparacion
# Out:
#     pc_number  cv_score  test_score                %_comp  cv_vs_baseline  \
# 0           4    0.5250      0.3875                  0.1%         -0.4300
# 1           7    0.7175      0.6875  0.16428571428571428%         -0.2375
# 2           9    0.8450      0.8375   0.2285714285714286%         -0.1100
# 3          12    0.8950      0.9000  0.29285714285714287%         -0.0600
# 4          15    0.9175      0.9250  0.35714285714285715%         -0.0375
# 5          17    0.9400      0.9250   0.4214285714285715%         -0.0150
# 6          20    0.9525      0.9375  0.48571428571428577%         -0.0025
# 7          23    0.9575      0.9500                 0.55%          0.0025
# 8          25    0.9575      0.9500   0.6142857142857143%          0.0025
# 9          28    0.9550      0.9375   0.6785714285714286%         -0.0000
# 10         30    0.9575      0.9625   0.7428571428571429%          0.0025
# 11         33    0.9600      0.9625   0.8071428571428573%          0.0050
# 12         36    0.9550      0.9750   0.8714285714285717%         -0.0000
# 13         38    0.9550      0.9750   0.9357142857142859%          0.0000
# 14         41    0.9575      0.9750                  1.0%          0.0025
#
#     test_vs_baseline
# 0            -0.5875
# 1            -0.2875
# 2            -0.1375
# 3            -0.0750
# 4            -0.0500
# 5            -0.0500
# 6            -0.0375
# 7            -0.0250
# 8            -0.0250
# 9            -0.0375
# 10           -0.0125
# 11           -0.0125
# 12            0.0000
# 13            0.0000
# 14            0.0000

# %% [markdown]
# *30 PCs sería el menor valor con el que perdemos menos de un 3% de sensibilidad media con respecto al baseline, sería una compresión del 0.75%.*

# %% [markdown]
# ### #EXTRA

# %% [markdown]
# 1. Para la segunda parte, visualiza en cuatro gráficos un scatter plot de las dos primeras componentes principales de la PCA escogida y colorea cada punto con las clases correspondientes a cada cara (como hay 40 clases, usa 10 por gráfico, 1-10 en el primero, 11-20 en el segundo, etc)
# 2. Para la tercer parte crea una función (modifica la de la práctica de la unidad de KMeans, por ejemplo) que permita ver la cara sin comprimir y la cara después de haberla descomprimido y haz una comprobación de cómo quedan (visualiza 5 caras por ejemplo) para cada uno de los valores de números de PCAs probados. Añade el caso para 150 y 300 PCs para que se vea que son las mismas claras con claridad.

# %% [markdown]
# #### *Extra 1*

# %%
pca_61 = PCA(n_components= 61)
X_train_pca = pd.DataFrame(pca_61.fit_transform(X_train), columns= [f"PC{i}" for i in range(1,62)], index= X_train.index)
train_pca = pd.concat((X_train_pca, y_train), axis = 1)

# %%
train_pca
# Out:
#          PC1     PC2     PC3     PC4     PC5     PC6     PC7     PC8     PC9  \
# 139   0.0570  1.7113 -2.7042 -1.3739 -1.4533  0.3819  1.0440  2.0711 -0.5814
# 58    9.9309 -5.0017  1.4829  1.4533  1.8222 -1.5785  1.4182 -0.0480  0.1944
# 34    2.8181  3.1815 -1.0920  1.3485 -0.9016 -0.6193  1.3588 -0.5400  0.4858
# 126   1.7189 -6.7514 -0.1497 -0.2830 -1.0758  1.1241  2.5382  0.6555 -1.1557
# 109   2.3308  5.3478  1.5835 -2.3930 -2.4418 -0.5690 -1.0912 -1.1991  2.0750
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 196   3.2726 -2.6573  0.3855  1.3450 -2.0935  0.2136  2.9353 -3.1662 -0.6879
# 278  -1.5949  2.1949 -1.6059 -3.9960  0.4491  1.6499  0.4829 -3.4817 -0.3096
# 216 -10.0487 -0.1533  0.0319  0.4268 -0.4153 -1.3384  0.0520 -2.2549 -0.4871
# 29    2.6488  1.0503 -2.9578  0.8311 -1.4245  1.0586  1.2499 -0.3376  1.0986
# 60    5.1370  1.2606  1.9050 -2.7928  1.9822 -1.6973 -2.2808 -1.6902  0.2226
#
#        PC10  ...    PC53    PC54    PC55    PC56    PC57    PC58    PC59  \
# 139 -1.2982  ...  0.1127 -0.7789 -0.0846  0.4565 -0.0465  0.2896  0.0680
# 58   0.0285  ...  0.3698 -0.0963  0.4783  0.2050  0.1995  0.9001 -0.1894
# 34  -0.0248  ... -0.7270 -0.3812  0.1442 -0.2133 -0.3990  0.5451  0.0727
# 126  0.2404  ...  0.9106 -0.4291  0.4702 -0.1159  0.2221 -0.3043 -0.4645
# 109 -0.2981  ... -0.4613  0.9830  0.1691 -0.2744 -0.2728 -0.0318 -0.2214
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 196 -0.8062  ... -0.8565 -0.3048 -0.2477  0.4869 -0.2033 -0.1773 -0.7378
# 278  0.6466  ... -0.4990 -0.2063  1.1226 -0.1644  0.5411  0.1255  0.6079
# 216 -0.0126  ... -0.5600 -0.2486  0.4869  0.1518 -0.0480  0.3596 -0.3872
# 29   0.3291  ... -0.0281  0.3310 -0.3002 -0.1812  0.1594  0.1361  0.4751
# 60  -0.0561  ...  0.1127 -0.4912 -0.4105  0.1653 -0.2393 -0.3194 -0.1020
#
#        PC60    PC61  target
# 139  0.3175 -0.1067      13
# 58  -0.5449 -0.2502       5
# 34   0.4337 -0.0684       3
# 126 -0.0314  0.3591      12
# 109  0.3281  0.0060      10
# ..      ...     ...     ...
# 196 -0.1819 -0.0263      19
# 278 -0.8934 -0.1971      27
# 216  0.1103 -0.0880      21
# 29  -0.7274  0.4140       2
# 60  -0.0254  0.6763       6
#
# [320 rows x 62 columns]

# %%
for i, j in zip(range(0, 40, 10), range(9, 41, 10)):
    plt.figure(figsize= (8,8))
    sns.scatterplot(train_pca.loc[train_pca.target.between(i, j, "both")], x = "PC1", y = "PC2", hue = "target", palette= "tab10")

# %% [markdown]
# *Hay valores de target que por algún motivo no representa, pero no alcanzo a entender por qué, cuando yo filtro el dataset sí que aparecen estos valores, pero en el scatter plot no se ven*

# %%
num_pcas = (np.linspace(0.001, 0.01, 15) * len(X.columns)).tolist()

# %%
def pinta_caras(faces,n_cols = 5, title = ""):
    faces = faces.reshape(-1, 64, 64)
    n_rows = ((len(faces) - 1) // n_cols + 1)
    plt.figure(figsize=(n_cols * 4, n_rows * 4.4))
    for index, face in enumerate(faces):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(face, cmap="gray")
        plt.axis("off")
    plt.title(title)
    plt.show()

# %%
for num_pca in num_pcas + [150,320]: # Añdimos 2 más para que se vea que son las mismas caras :-D
    num_pca = int(round(num_pca, 0))
    pca_temp = PCA(num_pca) # Por una cuestión de funcionamiento de la clase PCA tenemos que "comprimir" de nuevo no podemos usar el X_train_pca directamente
    X = pca_temp.fit_transform(X_train)
    X_train_temp = pca_temp.inverse_transform(X) # AQUI ESTA LA CLAVE, primero nos quedamos con el dataset pequeño y luego "descomprimimos"
    pinta_caras(X_train[0:5].values, title = "Sin comprimir")
    pinta_caras(X_train_temp[0:5], title = f"{round(num_pca/X_train_temp.shape[1]*100,2)}% de compresion ({num_pca} PCs)")
