# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pd.read_csv("2044.csv", sep=";").head()
# Out:
#               Tipo de alojamiento  Total Nacional  \
# 0  Encuesta de Ocupación Hotelera  Total Nacional
# 1  Encuesta de Ocupación Hotelera  Total Nacional
# 2  Encuesta de Ocupación Hotelera  Total Nacional
# 3  Encuesta de Ocupación Hotelera  Total Nacional
# 4  Encuesta de Ocupación Hotelera  Total Nacional
#
#   Comunidades y Ciudades Autónomas Residencia: Nivel 1 Residencia: Nivel 2  \
# 0                              NaN               Total                 NaN
# 1                              NaN               Total                 NaN
# 2                              NaN               Total                 NaN
# 3                              NaN               Total                 NaN
# 4                              NaN               Total                 NaN
#
#   Viajeros y pernoctaciones  Periodo       Total
# 0                   Viajero  2025M02   6.539.960
# 1                   Viajero  2025M01   5.776.075
# 2                   Viajero  2024M12   6.553.489
# ...

# %%
pd.read_csv("2941.csv", sep=";").loc[520:550, :]
# Out:
#                 Tipo de alojamiento  Total Nacional  \
# 520  Encuesta de Ocupación Hotelera  Total Nacional
# 521  Encuesta de Ocupación Hotelera  Total Nacional
# 522  Encuesta de Ocupación Hotelera  Total Nacional
# 523  Encuesta de Ocupación Hotelera  Total Nacional
# 524  Encuesta de Ocupación Hotelera  Total Nacional
# 525  Encuesta de Ocupación Hotelera  Total Nacional
# 526  Encuesta de Ocupación Hotelera  Total Nacional
# 527  Encuesta de Ocupación Hotelera  Total Nacional
# 528  Encuesta de Ocupación Hotelera  Total Nacional
# 529  Encuesta de Ocupación Hotelera  Total Nacional
# 530  Encuesta de Ocupación Hotelera  Total Nacional
# 531  Encuesta de Ocupación Hotelera  Total Nacional
# 532  Encuesta de Ocupación Hotelera  Total Nacional
# 533  Encuesta de Ocupación Hotelera  Total Nacional
# 534  Encuesta de Ocupación Hotelera  Total Nacional
# 535  Encuesta de Ocupación Hotelera  Total Nacional
# 536  Encuesta de Ocupación Hotelera  Total Nacional
# ...

# %%
# Out:
#         Tipo de alojamiento  Total Nacional  Comunidades y Ciudades Autónomas  \
# 0                      True            True                             False
# 1                      True            True                             False
# 2                      True            True                             False
# 3                      True            True                             False
# 4                      True            True                             False
# ...                     ...             ...                               ...
# 173995                 True            True                              True
# 173996                 True            True                              True
# 173997                 True            True                              True
# 173998                 True            True                              True
# 173999                 True            True                              True
#
# ...
